# %%
import json  
import pandas as pd  
from pandas.io.json import json_normalize  


with open('result.json') as f: 
    d = json.load(f) 
  
#lets put the data into a pandas df 
data = json_normalize(d) 

#get columns
for col in data.columns:   print(col)
# Out:
# data._id
# data.communication_recommendation
# data.content_count
# data.created
# data.custom_fields
# data.datasets
# data.gender
# data.liwc_scores.analytic
# data.liwc_scores.authentic
# data.liwc_scores.categories.AllPunc
# data.liwc_scores.categories.Apostro
# data.liwc_scores.categories.Colon
# data.liwc_scores.categories.Comma
# data.liwc_scores.categories.Dash
# data.liwc_scores.categories.Exclam
# data.liwc_scores.categories.OtherP
# data.liwc_scores.categories.Parenth
# data.liwc_scores.categories.Period
# data.liwc_scores.categories.QMark
# data.liwc_scores.categories.Quote
# data.liwc_scores.categories.SemiC
# data.liwc_scores.categories.achieve
# data.liwc_scores.categories.adj
# data.liwc_scores.categories.adverb
# data.liwc_scores.categories.affect
# data.liwc_scores.categories.affiliation
# data.liwc_scores.categories.anger
# data.liwc_scores.categories.anx
# data.liwc_scores.categories.article
# data.liwc_scores.categories.assent
# ...

# %%
topn = 10

traits = [
    "data.receptiviti_scores.percentiles.assertive",
    "data.receptiviti_scores.percentiles.imaginative"
]

traitlabels = map(lambda t: t, traits) 

print(traitlabels[0])
# tables = map(lambda t: {"trait": t}, traits) 

#                         data.sort_values(by=[t])[["name",t]].head(topn).reset_index()
print(tables)
                
# combinedtable = pd.concat(tables)
# display(combinedtable)

# for trait in traits:
#     top5 = data.sort_values(by=[trait])[["name",trait]].head()
#     display(top5)
#     print(top5.to_latex())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-792c6b4f4701> in <module>
#       8 traitlabels = map(lambda t: t, traits)
#       9
# ---> 10 print(traitlabels[0])
#      11 # tables = map(lambda t: {"trait": t}, traits)
#      12
#
# TypeError: 'map' object is not subscriptable
